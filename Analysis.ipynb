# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # LOADING DATA

# %%
survey_data = pd.read_csv("political_survey.csv")

# %%
survey_data.head()
# Out:
#    _index  district  ac  booth_no  intro1               q1  q2  q3  q4  \
# 0    3147         6  23       127     NaN            Arti    8   2  30
# 1    4086         6  23        79     NaN       Sasi kiran   8   2  54
# 2    4087         6  23        79     NaN           Urmela   8   2  46
# 3    4089         6  23        79     NaN           Vidiya   8   2  24
# 4    4090         6  23        79     NaN  Balwinder singh   8   1  45
#
#    q4_grid  ...  q12  q12_others  n_q13  q13  q13_others  q14  Accompainment  \
# 0        2  ...    1         NaN    NaN    2         NaN   13              2
# 1        3  ...    5         NaN    NaN    1         NaN    1              2
# 2        3  ...    5         NaN    NaN    1         NaN    1              2
# 3        1  ...    1         NaN    NaN    8         NaN    1              2
# 4        3  ...    5         NaN    NaN    2         NaN   16              2
#
#                                   _uuid   int_stime   int_etime
# ...

# %%
survey_data.tail()
# Out:
#      _index  district  ac  booth_no  intro1               q1  q2  q3  q4  \
# 909    6191         6  23         1     NaN     Jugraj singh   7   1  34
# 910    6192         6  23        43     NaN   Gurumukh singh   7   1  52
# 911    6193         6  23        43     NaN   Sharbjeet kaur   7   2  28
# 912    6195         6  23        43     NaN      Charn singh   7   1  55
# 913    6197         6  23        43     NaN  Sukhvinder kaur   7   2  56
#
#      q4_grid  ...  q12  q12_others  n_q13  q13  q13_others  q14  \
# 909        2  ...    5         NaN    NaN    3         NaN   15
# 910        3  ...    5         NaN    NaN    2         NaN   15
# 911        2  ...    5         NaN    NaN    1         NaN   13
# 912        3  ...    5         NaN    NaN    1         NaN    2
# 913        3  ...    5         NaN    NaN    1         NaN   13
#
#      Accompainment                                 _uuid   int_stime  \
# ...

# %%
survey_data.shape
# Out:
# (914, 51)

# %%
survey_data.columns
# Out:
# Index(['_index', 'district', 'ac', 'booth_no', 'intro1', 'q1', 'q2', 'q3',
#        'q4', 'q4_grid', 'q5', 'q6', 'q7a', 'q7b', 'q7c', 'q7d', 'q8a', 'q8a_1',
#        'q8a_1_others', 'q8b', 'q9a', 'q9b', 'q9b_others', 'n_q9b', 'n_q9b/1',
#        'n_q9c_1', 'q9c_1', 'n_q9c_1_001', 'n_q9c_1_001/1', 'n_q9c_2', 'q9c_2',
#        'n_q9c_2_001', 'n_q9c_2_001/1', 'q9c_others', 'q10a', 'q10a_others',
#        'q10b', 'n_q11', 'q11', 'q11_others', 'n_q12', 'q12', 'q12_others',
#        'n_q13', 'q13', 'q13_others', 'q14', 'Accompainment', '_uuid',
#        'int_stime', 'int_etime'],
#       dtype='object')

# %%
survey_data.isnull().sum()
# Out:
# _index             0
# district           0
# ac                 0
# booth_no           0
# intro1           914
# q1                 0
# q2                 0
# q3                 0
# q4                 0
# q4_grid            0
# q5                 0
# q6                 0
# q7a                0
# q7b              570
# q7c              704
# q7d              554
# q8a                0
# q8a_1              0
# q8a_1_others     914
# q8b                0
# q9a                0
# q9b              168
# q9b_others       914
# n_q9b            168
# n_q9b/1          168
# n_q9c_1          914
# q9c_1            746
# n_q9c_1_001      746
# n_q9c_1_001/1    746
# n_q9c_2          914
# q9c_2            746
# n_q9c_2_001      746
# n_q9c_2_001/1    746
# q9c_others       914
# q10a               0
# q10a_others      914
# q10b               0
# n_q11            914
# q11                0
# q11_others       914
# n_q12            914
# q12                0
# q12_others       914
# ...

# %% [markdown]
# # DROPPING COLUMNS

# %%
survey_data_1 = survey_data.drop(['intro1', 'q8a_1_others',
                               'q9b_others', 'n_q9b', 'n_q9b/1', 'n_q9c_1', 
                                'q9c_1', 'n_q9c_1_001', 'n_q9c_1_001/1', 'n_q9c_2', 
                                'q9c_2','n_q9c_2_001', 'n_q9c_2_001/1', 'q9c_others',
                               'q10a_others', 'n_q11', 'q11_others', 'n_q12', 'q12_others',
                               'n_q13', 'q13_others'], axis = 1)

# %%
survey_data_1.isnull().sum()
# Out:
# _index             0
# district           0
# ac                 0
# booth_no           0
# q1                 0
# q2                 0
# q3                 0
# q4                 0
# q4_grid            0
# q5                 0
# q6                 0
# q7a                0
# q7b              570
# q7c              704
# q7d              554
# q8a                0
# q8a_1              0
# q8b                0
# q9a                0
# q9b              168
# q10a               0
# q10b               0
# q11                0
# q12                0
# q13                0
# q14                0
# Accompainment      0
# _uuid              0
# int_stime          0
# int_etime          0
# dtype: int64

# %%
survey_data_2 = survey_data_1.drop(['q7b', 'q7c','q7d', 'q9b', '_uuid',
                                   'int_stime', 'int_etime'], axis = 1)

# %%
survey_data_2.isnull().sum()
# Out:
# _index           0
# district         0
# ac               0
# booth_no         0
# q1               0
# q2               0
# q3               0
# q4               0
# q4_grid          0
# q5               0
# q6               0
# q7a              0
# q8a              0
# q8a_1            0
# q8b              0
# q9a              0
# q10a             0
# q10b             0
# q11              0
# q12              0
# q13              0
# q14              0
# Accompainment    0
# dtype: int64

# %%
survey_data_2 = survey_data_2.drop(['_index', 'q1'], axis = 1)

# %% [markdown]
# # CALCULATING VALUE COUNTS

# %%
survey_data_2['q11'].unique()
# Out:
# array([ 1,  5, 18,  8,  4,  3, 11, 10,  2,  7,  6,  9], dtype=int64)

# %%
survey_data_2['q11'].value_counts()
# Out:
# 5     552
# 1     242
# 4      67
# 18     24
# 8      11
# 3       5
# 10      3
# 6       3
# 2       3
# 9       2
# 11      1
# 7       1
# Name: q11, dtype: int64

# %%
survey_data_2['q12'].unique()
# Out:
# array([ 1,  5,  4, 18, 13,  3, 12,  2], dtype=int64)

# %%
survey_data_2['q12'].value_counts()
# Out:
# 5     590
# 1     211
# 4      82
# 18     24
# 13      3
# 3       2
# 12      1
# 2       1
# Name: q12, dtype: int64

# %%
survey_data_2['q8a_1'].unique()
# Out:
# array([ 1,  5, 18,  4,  3], dtype=int64)

# %%
survey_data_2['q8a_1'].value_counts()
# Out:
# 1     751
# 5     123
# 4      38
# 18      1
# 3       1
# Name: q8a_1, dtype: int64

# %%
survey_data['q9b'].unique()
# Out:
# array([ 1.,  4., nan,  5., 10.,  8., 18.,  3., 12., 11.,  2.,  9.])

# %%
survey_data['q9b'].value_counts()
# Out:
# 5.0     449
# 4.0     160
# 1.0     116
# 8.0       9
# 18.0      4
# 9.0       2
# 3.0       2
# 2.0       1
# 11.0      1
# 12.0      1
# 10.0      1
# Name: q9b, dtype: int64

# %% [markdown]
# # CREATING DATAFRAME

# %%
data = {'party_name': [1,  5, 18,  8,  4,  3, 11, 10,  2,  7,  6,  9 , 12],
       'q8a_1': [751,123, 1, 0, 38, 1, 0 , 0, 0, 0, 0, 0, 0],
       'q9b': [116, 449, 4, 9, 160, 2, 1, 1, 1, 0, 0, 2, 1],
       'q11': [242, 552, 24, 11, 67, 5, 1, 3, 3, 1, 3, 2, 0],
       'q12': [211, 590, 24, 0, 82, 2, 0, 0, 1, 0, 0, 0, 1 ]}

# %%
df1 = pd.DataFrame(data)

# %%
df1
# Out:
#     party_name  q8a_1  q9b  q11  q12
# 0            1    751  116  242  211
# 1            5    123  449  552  590
# 2           18      1    4   24   24
# 3            8      0    9   11    0
# 4            4     38  160   67   82
# 5            3      1    2    5    2
# 6           11      0    1    1    0
# 7           10      0    1    3    0
# 8            2      0    1    3    1
# 9            7      0    0    1    0
# 10           6      0    0    3    0
# 11           9      0    2    2    0
# 12          12      0    1    0    1

# %%
df1['2012'] = df1['q8a_1'].div(df1['q8a_1'].sum())

# %%
df1['2014'] = df1['q9b'].div(df1['q9b'].sum())

# %%
df1['2017'] = df1['q11'].div(df1['q11'].sum())

# %%
df1['2019'] = df1['q12'].div(df1['q12'].sum())

# %%
df1
# Out:
#     party_name  q8a_1  q9b  q11  q12      2012      2014      2017      2019
# 0            1    751  116  242  211  0.821663  0.155496  0.264770  0.231614
# 1            5    123  449  552  590  0.134573  0.601877  0.603939  0.647640
# 2           18      1    4   24   24  0.001094  0.005362  0.026258  0.026345
# 3            8      0    9   11    0  0.000000  0.012064  0.012035  0.000000
# 4            4     38  160   67   82  0.041575  0.214477  0.073304  0.090011
# 5            3      1    2    5    2  0.001094  0.002681  0.005470  0.002195
# 6           11      0    1    1    0  0.000000  0.001340  0.001094  0.000000
# 7           10      0    1    3    0  0.000000  0.001340  0.003282  0.000000
# 8            2      0    1    3    1  0.000000  0.001340  0.003282  0.001098
# 9            7      0    0    1    0  0.000000  0.000000  0.001094  0.000000
# 10           6      0    0    3    0  0.000000  0.000000  0.003282  0.000000
# ...

# %%
df1['expected'] = ((df1['q8a_1'] * df1['2012']) + (df1['q9b'] * df1['2014']) + (df1['q11'] * df1['2017']) + (df1['q12'] * df1['2019'])).div(df1['q8a_1'] + df1['q9b'] + df1['q11'] + df1['q12'])

# %%
df1
# Out:
#     party_name  q8a_1  q9b  q11  q12      2012      2014      2017      2019  \
# 0            1    751  116  242  211  0.821663  0.155496  0.264770  0.231614
# 1            5    123  449  552  590  0.134573  0.601877  0.603939  0.647640
# 2           18      1    4   24   24  0.001094  0.005362  0.026258  0.026345
# 3            8      0    9   11    0  0.000000  0.012064  0.012035  0.000000
# 4            4     38  160   67   82  0.041575  0.214477  0.073304  0.090011
# 5            3      1    2    5    2  0.001094  0.002681  0.005470  0.002195
# 6           11      0    1    1    0  0.000000  0.001340  0.001094  0.000000
# 7           10      0    1    3    0  0.000000  0.001340  0.003282  0.000000
# 8            2      0    1    3    1  0.000000  0.001340  0.003282  0.001098
# 9            7      0    0    1    0  0.000000  0.000000  0.001094  0.000000
# 10           6      0    0    3    0  0.000000  0.000000  0.003282  0.000000
# ...

# %% [markdown]
# # CALCULATING EXPECTED VOTE SHARE

# %%
df1['vote_share'] = df1['expected'] * 100

# %%
df1
# Out:
#     party_name  q8a_1  q9b  q11  q12      2012      2014      2017      2019  \
# 0            1    751  116  242  211  0.821663  0.155496  0.264770  0.231614
# 1            5    123  449  552  590  0.134573  0.601877  0.603939  0.647640
# 2           18      1    4   24   24  0.001094  0.005362  0.026258  0.026345
# 3            8      0    9   11    0  0.000000  0.012064  0.012035  0.000000
# 4            4     38  160   67   82  0.041575  0.214477  0.073304  0.090011
# 5            3      1    2    5    2  0.001094  0.002681  0.005470  0.002195
# 6           11      0    1    1    0  0.000000  0.001340  0.001094  0.000000
# 7           10      0    1    3    0  0.000000  0.001340  0.003282  0.000000
# 8            2      0    1    3    1  0.000000  0.001340  0.003282  0.001098
# 9            7      0    0    1    0  0.000000  0.000000  0.001094  0.000000
# 10           6      0    0    3    0  0.000000  0.000000  0.003282  0.000000
# ...

# %%
df1.to_csv('Survey1.csv', index = False)

# %%
df1.party_name.value_counts()
# Out:
# 18    1
# 12    1
# 11    1
# 10    1
# 9     1
# 8     1
# 7     1
# 6     1
# 5     1
# 4     1
# 3     1
# 2     1
# 1     1
# Name: party_name, dtype: int64

# %% [markdown]
# # DATA VISUALIZATION

# %% [raw]
# PART NAME VS VOTE SHARE

# %%
plt.figure(figsize=(15,6))
sns.barplot(x = 'party_name', y = 'vote_share', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x = 'party_name', y = 'vote_share', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.histplot(x = 'party_name', y = 'vote_share', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x = 'party_name', y = 'vote_share', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.stripplot(x = 'party_name', y = 'vote_share', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.lineplot(x = 'party_name', y = 'vote_share', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.kdeplot(x = 'party_name', y = 'vote_share', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.factorplot(x = 'party_name', y = 'vote_share', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.swarmplot(x = 'party_name', y = 'vote_share', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.violinplot(x = 'party_name', y = 'vote_share', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %% [raw]
# PARTY NAME VS 2012

# %%
plt.figure(figsize=(15,6))
sns.barplot(x = 'party_name', y = '2012', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x = 'party_name', y = '2012', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.histplot(x = 'party_name', y = '2012', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x = 'party_name', y = '2012', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.lineplot(x = 'party_name', y = '2012', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.stripplot(x = 'party_name', y = '2012', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.kdeplot(x = 'party_name', y = '2012', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.factorplot(x = 'party_name', y = '2012', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %% [raw]
# 2012 VS VOTE SHARE

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x = '2012', y = 'vote_share', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.barplot(x = '2012', y = 'vote_share', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x = '2012', y = 'vote_share', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.lineplot(x = '2012', y = 'vote_share', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.kdeplot(x = '2012', y = 'vote_share', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.factorplot(x = '2012', y = 'vote_share', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %% [raw]
# PARTY NAME VS 2014

# %%
plt.figure(figsize=(15,6))
sns.barplot(x = 'party_name', y = '2014', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x = 'party_name', y = '2014', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x = 'party_name', y = '2014', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.lineplot(x = 'party_name', y = '2014', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.kdeplot(x = 'party_name', y = '2014', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.factorplot(x = 'party_name', y = '2014', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %% [raw]
# 2014 VS VOTE SHARE

# %%
plt.figure(figsize=(15,6))
sns.barplot(x = '2014', y = 'vote_share', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x = '2014', y = 'vote_share', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x = '2014', y = 'vote_share', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.lineplot(x = '2014', y = 'vote_share', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.kdeplot(x = '2014', y = 'vote_share', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.factorplot(x = '2014', y = 'vote_share', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %% [raw]
# PARTY NAME VS 2017

# %%
plt.figure(figsize=(15,6))
sns.barplot(x = 'party_name', y = '2017', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x = 'party_name', y = '2017', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x = 'party_name', y = '2017', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x = 'party_name', y = '2017', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.lineplot(x = 'party_name', y = '2017', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.kdeplot(x = 'party_name', y = '2017', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.factorplot(x = 'party_name', y = '2017', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %% [raw]
# 2017 VS VOTE SHARE

# %%
plt.figure(figsize=(15,6))
sns.barplot(x = '2017', y = 'vote_share', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x = '2017', y = 'vote_share', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x = '2017', y = 'vote_share', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.lineplot(x = '2017', y = 'vote_share', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.kdeplot(x = '2017', y = 'vote_share', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.factorplot(x = '2017', y = 'vote_share', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %% [raw]
# PARTY NAME VS 2019

# %%
plt.figure(figsize=(15,6))
sns.barplot(x = 'party_name', y = '2019', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x = 'party_name', y = '2019', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x = 'party_name', y = '2019', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.lineplot(x = 'party_name', y = '2019', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.kdeplot(x = 'party_name', y = '2019', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.factorplot(x = 'party_name', y = '2019', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %% [raw]
# 2019 VS VOTE SHARE

# %%
plt.figure(figsize=(15,6))
sns.barplot(x = '2019', y = 'vote_share', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x = '2019', y = 'vote_share', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x = '2019', y = 'vote_share', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.lineplot(x = '2019', y = 'vote_share', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.kdeplot(x = '2019', y = 'vote_share', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.factorplot(x = '2019', y = 'vote_share', data = df1, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # CONVERTING TO LIST

# %%
l1 = df1['q8a_1'].tolist()

# %%
l2 = df1['q9b'].tolist()

# %%
l3 = df1['q11'].tolist()

# %%
l4 = df1['q12'].tolist()

# %%
m = [l1,l2,l3,l4]

# %%
m = np.array(m)

# %%
df1['sum'] = df1['q8a_1'] + df1['q9b'] + df1['q11'] + df1['q12']

# %%
s1 = df1['q8a_1'].sum()

# %%
s2 = df1['q9b'].sum()

# %%
s3 = df1['q11'].sum()

# %%
s4 = df1['q12'].sum()

# %%
print(s1,s2,s3,s4)
# Out:
# 914 746 914 911

# %%
df1['sum']
# Out:
# 0     1320
# 1     1714
# 2       53
# 3       20
# 4      347
# 5       10
# 6        2
# 7        4
# 8        5
# 9        1
# 10       3
# 11       4
# 12       2
# Name: sum, dtype: int64

# %% [markdown]
# # AGGREGATION AND GROUPING

# %%
xip = np.array([1400,1800, 100, 50, 400, 50, 10, 10, 10, 10, 10, 10, 10])
xpj = np.array([1000, 800, 1000, 1000])

# %%
aggregates = [xip, xpj]
dimensions = [[2]]

# %% [markdown]
# # USING IPF METHOD

# %%
from ipfn import ipfn

# %%
IPF = ipfn.ipfn(m, aggregates, dimensions)

# %% [markdown]
# # FINDING PARTY WISE VOTE SHARE

# %%
survey_data_age_gender_cast = survey_data[['q3', 'q4_grid', 'q7b', 'q8a_1','q9b',
                                          'q11', 'q12']]

# %%
survey_data_age_gender_cast
# Out:
#      q3  q4_grid  q7b  q8a_1  q9b  q11  q12
# 0     2        2  NaN      1  1.0    1    1
# 1     2        3  NaN      1  4.0    5    5
# 2     2        3  NaN      1  NaN    5    5
# 3     2        1  NaN      5  5.0   18    1
# 4     1        3  NaN      1  NaN    5    5
# ..   ..      ...  ...    ...  ...  ...  ...
# 909   1        2  1.0      1  5.0    5    5
# 910   1        3  NaN      1  5.0    5    5
# 911   2        2  1.0      1  1.0    4    5
# 912   1        3  1.0      1  5.0    5    5
# 913   2        3  NaN      1  5.0    5    5
#
# [914 rows x 7 columns]

# %%
survey_data_age_gender_cast['q3'].unique()
# Out:
# array([2, 1], dtype=int64)

# %%
survey_data_age_gender_cast['q3'].value_counts()
# Out:
# 1    496
# 2    418
# Name: q3, dtype: int64

# %%
survey_data_gender = survey_data_age_gender_cast.groupby(['q8a_1', 'q3'])['q3'].count()

# %%
survey_data_gender
# Out:
# q8a_1  q3
# 1      1     385
#        2     366
# 3      2       1
# 4      1      31
#        2       7
# 5      1      79
#        2      44
# 18     1       1
# Name: q3, dtype: int64

# %%
survey_data_gender = survey_data_age_gender_cast.groupby(['q9b', 'q3'])['q3'].count()

# %%
survey_data_gender
# Out:
# q9b   q3
# 1.0   1      64
#       2      52
# 2.0   2       1
# 3.0   1       2
# 4.0   1      96
#       2      64
# 5.0   1     242
#       2     207
# 8.0   1       5
#       2       4
# 9.0   1       2
# 10.0  2       1
# 11.0  2       1
# 12.0  2       1
# 18.0  1       1
#       2       3
# Name: q3, dtype: int64

# %%
survey_data_gender = survey_data_age_gender_cast.groupby(['q11', 'q3'])['q3'].count()

# %%
survey_data_gender
# Out:
# q11  q3
# 1    1     135
#      2     107
# 2    1       2
#      2       1
# 3    1       2
#      2       3
# 4    1      42
#      2      25
# 5    1     284
#      2     268
# 6    1       3
# 7    2       1
# 8    1       7
#      2       4
# 9    2       2
# 10   1       1
#      2       2
# 11   1       1
# 18   1      19
#      2       5
# Name: q3, dtype: int64

# %%
survey_data_gender = survey_data_age_gender_cast.groupby(['q12', 'q3'])['q3'].count()

# %%
survey_data_gender
# Out:
# q12  q3
# 1    1     120
#      2      91
# 2    1       1
# 3    1       1
#      2       1
# 4    1      49
#      2      33
# 5    1     303
#      2     287
# 12   1       1
# 13   1       1
#      2       2
# 18   1      20
#      2       4
# Name: q3, dtype: int64

# %%
survey_data_age = survey_data_age_gender_cast.groupby(['q8a_1', 'q4_grid'])['q4_grid'].count()

# %%
survey_data_age
# Out:
# q8a_1  q4_grid
# 1      1           93
#        2          373
#        3          285
# 3      3            1
# 4      1           11
#        2           19
#        3            8
# 5      1           13
#        2           61
#        3           49
# 18     1            1
# Name: q4_grid, dtype: int64

# %%
survey_data_age = survey_data_age_gender_cast.groupby(['q9b', 'q4_grid'])['q4_grid'].count()

# %%
survey_data_age
# Out:
# q9b   q4_grid
# 1.0   1           11
#       2           67
#       3           38
# 2.0   3            1
# 3.0   2            2
# 4.0   1           32
#       2           77
#       3           51
# 5.0   1           50
#       2          215
#       3          184
# 8.0   2            3
#       3            6
# 9.0   2            2
# 10.0  2            1
# 11.0  3            1
# 12.0  2            1
# 18.0  2            2
#       3            2
# Name: q4_grid, dtype: int64

# %%
survey_data_age = survey_data_age_gender_cast.groupby(['q11', 'q4_grid'])['q4_grid'].count()

# %%
survey_data_age
# Out:
# q11  q4_grid
# 1    1           15
#      2          131
#      3           96
# 2    1            2
#      2            1
# 3    2            1
#      3            4
# 4    1           14
#      2           35
#      3           18
# 5    1           61
#      2          268
#      3          223
# 6    2            3
# 7    2            1
# 8    1            1
#      2            8
#      3            2
# 9    2            2
# 10   1            1
#      2            2
# 11   1            1
# 18   1           23
#      2            1
# Name: q4_grid, dtype: int64

# %%
survey_data_age = survey_data_age_gender_cast.groupby(['q12', 'q4_grid'])['q4_grid'].count()

# %%
survey_data_age
# Out:
# q12  q4_grid
# 1    1           21
#      2          108
#      3           82
# 2    1            1
# 3    1            2
# 4    1           11
#      2           48
#      3           23
# 5    1           61
#      2          292
#      3          237
# 12   2            1
# 13   1            2
#      2            1
# 18   1           20
#      2            3
#      3            1
# Name: q4_grid, dtype: int64

# %%
survey_data_caste = survey_data_age_gender_cast.groupby(['q8a_1', 'q7b'])['q7b'].count()

# %%
survey_data_caste
# Out:
# q8a_1  q7b
# 1      1.0    207
#        2.0     13
#        3.0     10
#        4.0      5
#        5.0     21
#        6.0     12
# 4      1.0      9
#        2.0      2
#        6.0      6
# 5      1.0     26
#        2.0      2
#        4.0      2
#        5.0      5
#        6.0     24
# Name: q7b, dtype: int64

# %%
survey_data_caste = survey_data_age_gender_cast.groupby(['q9b', 'q7b'])['q7b'].count()

# %%
survey_data_caste
# Out:
# q9b   q7b
# 1.0   1.0     44
#       2.0      2
#       3.0      2
#       4.0      1
#       5.0      6
#       6.0      4
# 2.0   1.0      1
# 3.0   1.0      1
# 4.0   1.0     42
#       2.0      4
#       3.0      1
#       4.0      1
#       5.0      3
#       6.0      9
# 5.0   1.0    109
#       2.0      4
#       3.0      5
#       4.0      3
#       5.0     16
#       6.0     26
# 8.0   1.0      2
#       2.0      2
#       6.0      3
# 18.0  1.0      3
# Name: q7b, dtype: int64

# %%
survey_data_caste = survey_data_age_gender_cast.groupby(['q11', 'q7b'])['q7b'].count()

# %%
survey_data_caste
# Out:
# q11  q7b
# 1    1.0     71
#      2.0      4
#      3.0      5
#      4.0      1
#      5.0      7
#      6.0     18
# 3    5.0      1
# 4    1.0     16
#      2.0      2
#      4.0      2
#      5.0      2
#      6.0      8
# 5    1.0    143
#      2.0     10
#      3.0      4
#      4.0      3
#      5.0     14
#      6.0     16
# 6    1.0      2
# 8    1.0      5
#      5.0      2
# 10   1.0      1
# 18   1.0      4
#      2.0      1
#      3.0      1
#      4.0      1
# Name: q7b, dtype: int64

# %%
survey_data_caste = survey_data_age_gender_cast.groupby(['q12', 'q7b'])['q7b'].count()

# %%
survey_data_caste
# Out:
# q12  q7b
# 1    1.0     68
#      2.0      4
#      3.0      1
#      4.0      1
#      5.0      9
#      6.0     14
# 2    1.0      1
# 4    1.0     19
#      2.0      2
#      3.0      1
#      4.0      1
#      5.0      2
#      6.0     10
# 5    1.0    150
#      2.0     10
#      3.0      8
#      4.0      4
#      5.0     15
#      6.0     18
# 13   1.0      1
# 18   1.0      3
#      2.0      1
#      4.0      1
# Name: q7b, dtype: int64

# %% [markdown]
# # PERFORMING ANALYSIS AT DISTRICT, ASSEMBLY CONSTITUENCY LEVEL

# %%
survey_data_district_assembly = survey_data[['district', 'ac', 'q8a_1','q9b',
                                          'q11', 'q12']]

# %%
survey_data_district = survey_data_district_assembly.groupby(['q8a_1', 'district'])['district'].count()

# %%
survey_data_district
# Out:
# q8a_1  district
# 1      6           751
# 3      6             1
# 4      6            38
# 5      6           123
# 18     6             1
# Name: district, dtype: int64

# %%
survey_data_district = survey_data_district_assembly.groupby(['q9b', 'district'])['district'].count()

# %%
survey_data_district
# Out:
# q9b   district
# 1.0   6           116
# 2.0   6             1
# 3.0   6             2
# 4.0   6           160
# 5.0   6           449
# 8.0   6             9
# 9.0   6             2
# 10.0  6             1
# 11.0  6             1
# 12.0  6             1
# 18.0  6             4
# Name: district, dtype: int64

# %%
survey_data_district = survey_data_district_assembly.groupby(['q11', 'district'])['district'].count()

# %%
survey_data_district
# Out:
# q11  district
# 1    6           242
# 2    6             3
# 3    6             5
# 4    6            67
# 5    6           552
# 6    6             3
# 7    6             1
# 8    6            11
# 9    6             2
# 10   6             3
# 11   6             1
# 18   6            24
# Name: district, dtype: int64

# %%
survey_data_district = survey_data_district_assembly.groupby(['q12', 'district'])['district'].count()

# %%
survey_data_district
# Out:
# q12  district
# 1    6           211
# 2    6             1
# 3    6             2
# 4    6            82
# 5    6           590
# 12   6             1
# 13   6             3
# 18   6            24
# Name: district, dtype: int64

# %%
survey_data_assembly = survey_data_district_assembly.groupby(['q8a_1', 'ac'])['ac'].count()

# %%
survey_data_assembly
# Out:
# q8a_1  ac
# 1      23    751
# 3      23      1
# 4      23     38
# 5      23    123
# 18     23      1
# Name: ac, dtype: int64

# %%
survey_data_assembly = survey_data_district_assembly.groupby(['q9b', 'ac'])['ac'].count()

# %%
survey_data_assembly
# Out:
# q9b   ac
# 1.0   23    116
# 2.0   23      1
# 3.0   23      2
# 4.0   23    160
# 5.0   23    449
# 8.0   23      9
# 9.0   23      2
# 10.0  23      1
# 11.0  23      1
# 12.0  23      1
# 18.0  23      4
# Name: ac, dtype: int64

# %%
survey_data_assembly = survey_data_district_assembly.groupby(['q11', 'ac'])['ac'].count()

# %%
survey_data_assembly
# Out:
# q11  ac
# 1    23    242
# 2    23      3
# 3    23      5
# 4    23     67
# 5    23    552
# 6    23      3
# 7    23      1
# 8    23     11
# 9    23      2
# 10   23      3
# 11   23      1
# 18   23     24
# Name: ac, dtype: int64

# %%
survey_data_assembly = survey_data_district_assembly.groupby(['q12', 'ac'])['ac'].count()

# %%
survey_data_assembly
# Out:
# q12  ac
# 1    23    211
# 2    23      1
# 3    23      2
# 4    23     82
# 5    23    590
# 12   23      1
# 13   23      3
# 18   23     24
# Name: ac, dtype: int64

# %% [markdown]
# # TASK NO : 2
# CATEGORISE EACH BOOTH WITH RESPECT TO A PARTICULAR PARTY

# %%
booth_data_2012 = pd.read_csv("2012.csv")

# %%
booth_data_2012.head()
# Out:
#    AC Number  Booth Number 2012  SAD-BJP  AAP    INC   BSP  Others  \
# 0         88                  1    45.64    0  38.43  1.04   14.90
# 1         88                  2    44.98    0  35.78  0.93   18.31
# 2         88                  3    36.81    0  35.73  0.24   27.22
# 3         88                  4    46.96    0  31.53  0.66   20.85
# 4         88                  5    54.09    0  31.62  0.00   14.29
#
#    Total Valid Vote
# 0              1054
# 1              1076
# 2               834
# 3               609
# 4               623

# %%
booth_data_2012.tail()
# Out:
#      AC Number  Booth Number 2012  SAD-BJP  AAP    INC   BSP  Others  \
# 271         89                136    28.86    0  65.46  0.48    5.19
# 272         89                137    42.24    0  49.53  1.75    6.48
# 273         89                138    39.67    0  50.53  3.17    6.64
# 274         89                139    41.03    0  46.18  1.03   11.76
# 275         89                140    51.80    0  32.89  0.19   15.12
#
#      Total Valid Vote
# 271               828
# 272               741
# 273               663
# 274               680
# 275               529

# %%
booth_data_2012_88 = booth_data_2012[booth_data_2012['AC Number'] == 88]

# %%
booth_data_2012_88['max'] = booth_data_2012_88[['SAD-BJP', 'AAP', 'INC', 'BSP', 'Others']].max(axis = 1)

# %%
booth_data_2012_88
# Out:
#      AC Number  Booth Number 2012  SAD-BJP  AAP    INC   BSP  Others  \
# 0           88                  1    45.64    0  38.43  1.04   14.90
# 1           88                  2    44.98    0  35.78  0.93   18.31
# 2           88                  3    36.81    0  35.73  0.24   27.22
# 3           88                  4    46.96    0  31.53  0.66   20.85
# 4           88                  5    54.09    0  31.62  0.00   14.29
# ..         ...                ...      ...  ...    ...   ...     ...
# 131         88                132    51.60    0  24.20  3.88   20.32
# 132         88                133    40.87    0  27.38  1.93   29.82
# 133         88                134    49.09    0  24.89  0.23   25.80
# 134         88                135    37.99    0  29.67  0.63   31.71
# 135         88                136    50.00    0  23.06  0.00   26.94
#
#      Total Valid Vote    max
# 0                1054  45.64
# 1                1076  44.98
# 2                 834  36.81
# ...

# %%
booth_data_2014 = pd.read_csv("2014.csv")

# %%
booth_data_2014 .head()
# Out:
#    AC Number  Booth Number 2014  SAD-BJP    AAP    INC   BSP  Others  \
# 0         88                  1    27.61  43.05  26.64  0.19    2.51
# 1         88                  2    24.72  42.60  24.06  0.44    8.17
# 2         88                  3    31.56  38.93  25.00  0.00    4.51
# 3         88                  4    34.31  41.08  20.77  0.90    2.93
# 4         88                  5    19.00  56.25  14.62  0.75    9.38
#
#    Total Valid Vote
# 0               518
# 1               453
# 2               488
# 3               443
# 4               800

# %%
booth_data_2014.tail()
# Out:
#      AC Number  Booth Number 2014  SAD-BJP    AAP    INC   BSP  Others  \
# 304         89                148    24.36  30.36  41.33  0.13    3.83
# 305         89                149    29.03  34.16  33.28  0.00    3.52
# 306         89                150    26.77  31.97  36.06  0.63    4.57
# 307         89                151    33.02  48.13  15.58  0.93    2.34
# 308         89                152    31.04  56.97  10.76  0.00    1.23
#
#      Total Valid Vote
# 304               784
# 305               682
# 306               635
# 307               642
# 308               567

# %%
booth_data_2014_88 = booth_data_2014[booth_data_2014['AC Number'] == 88]

# %%
booth_data_2014_88['max'] = booth_data_2014_88[['SAD-BJP', 'AAP', 'INC', 'BSP', 'Others']].max(axis = 1)

# %%
booth_data_2014_88
# Out:
#      AC Number  Booth Number 2014  SAD-BJP    AAP    INC   BSP  Others  \
# 0           88                  1    27.61  43.05  26.64  0.19    2.51
# 1           88                  2    24.72  42.60  24.06  0.44    8.17
# 2           88                  3    31.56  38.93  25.00  0.00    4.51
# 3           88                  4    34.31  41.08  20.77  0.90    2.93
# 4           88                  5    19.00  56.25  14.62  0.75    9.38
# ..         ...                ...      ...    ...    ...   ...     ...
# 152         88                153    23.02  43.26  28.14  1.63    3.95
# 153         88                154    15.58  45.12  33.02  0.47    5.81
# 154         88                155    24.45  47.40  25.41  0.41    2.32
# 155         88                156    19.43  52.19  25.14  0.00    3.24
# 156         88                157    52.88  12.30  31.41  0.52    2.88
#
#      Total Valid Vote    max
# 0                 518  43.05
# 1                 453  42.60
# ...

# %%
booth_data_2017 = pd.read_csv("2017.csv")

# %%
booth_data_2017.head()
# Out:
#    AC Number Booth Number 2017  SAD-BJP    AAP    INC   BSP  Others  \
# 0         88                 1    26.99  51.63  18.66  1.09    1.63
# 1         88                 2    34.45  38.18  23.46  0.00    3.91
# 2         88                 3    25.52  49.76  23.11  0.16    1.44
# 3         88                 4    34.35  45.41  19.22  0.34    0.68
# 4         88                 5    17.98  35.31  44.03  0.75    1.94
#
#    Total Valid Vote
# 0               552
# 1               537
# 2               623
# 3               588
# 4               929

# %%
booth_data_2017.tail()
# Out:
#      AC Number Booth Number 2017  SAD-BJP    AAP    INC   BSP  Others  \
# 306         89               149    29.96  35.32  31.06  0.49    3.17
# 307         89               150    36.71  30.39  28.55  1.71    2.64
# 308         89               151    23.48  32.67  39.89  0.42    3.54
# 309         89               152    31.10  44.33  22.16  0.52    1.89
# 310         89            POSTAL    15.13  66.90  16.31  0.71    0.95
#
#      Total Valid Vote
# 306               821
# 307               760
# 308               707
# 309               582
# 310               423

# %%
booth_data_2017_88 = booth_data_2017[booth_data_2017['AC Number'] == 88]

# %%
booth_data_2017_88['max'] = booth_data_2017_88[['SAD-BJP', 'AAP', 'INC', 'BSP', 'Others']].max(axis = 1)

# %%
booth_data_2017_88
# Out:
#      AC Number Booth Number 2017  SAD-BJP    AAP    INC   BSP  Others  \
# 0           88                 1    26.99  51.63  18.66  1.09    1.63
# 1           88                 2    34.45  38.18  23.46  0.00    3.91
# 2           88                 3    25.52  49.76  23.11  0.16    1.44
# 3           88                 4    34.35  45.41  19.22  0.34    0.68
# 4           88                 5    17.98  35.31  44.03  0.75    1.94
# ..         ...               ...      ...    ...    ...   ...     ...
# 153         88               154    12.47  30.27  54.19  2.45    0.61
# 154         88               155    28.24  39.87  30.45  0.44    1.00
# 155         88               156    22.79  33.38  41.18  0.59    2.06
# 156         88               157    53.32  16.46  28.75  0.49    0.98
# 157         88            POSTAL    19.25  63.27  16.37  1.11    0.00
#
#      Total Valid Vote    max
# 0                 552  51.63
# 1                 537  38.18
# 2                 623  49.76
# ...
